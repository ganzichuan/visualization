# %% [markdown]
# Life expectancy example:
# 1. yes
# 2. no, 3D is not really a good idea, need clearer X and Y axis definition, no source cited
# 3. yes, to compare different life expectancy across the continents
# 4. yes, it's easy to differentiate
#
# Monstrous costs example:
# 1. no, catchy but not clear
# 2. no, no clear scale, no label
# 3. no, not clear which political message it tries to convey
# 4. no, it's just catchy
#
# Comparison example
# 1. yes
# 2. no, no source
# 3. not really, hard to tell the top and bottom line
# 4. no
#
# Presidential run example
# 1. no, too shiny
# 2. yes but the different parts look the same size
# 3. not really
# 4. maybe
#
# Wind map example
# in general very good dynamic visualization but a little more color would be better

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0,100,50)

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.scatter(x,y)

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y)

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y)
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Year since start')
fig.tight_layout()

# %%
font1={'family':'sans-serif','color':'blue','size':20}
font2={'family':'monospace','color':'green','size':14}

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y)
ax.set_title('Total growth over time',fontdict=font1)
ax.set_ylabel('Total growth',fontdict=font2)
ax.set_xlabel('Year since start',fontdict=font2)
fig.tight_layout()

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.scatter(x,y,marker='*',color='indigo')

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y,marker='*',color='indigo',linestyle='--',linewidth='2')

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y,marker='*',markersize='12',color='#7425b9',linestyle='--',linewidth='2',markeredgecolor='#fa9359',markerfacecolor='#000000')

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.grid(axis='y',color='blue',linewidth=2,linestyle='-.')
ax.plot(x,y,marker='*',markersize='12',color='#7425b9',linestyle='--',linewidth='2',markeredgecolor='#fa9359',markerfacecolor='#000000')
